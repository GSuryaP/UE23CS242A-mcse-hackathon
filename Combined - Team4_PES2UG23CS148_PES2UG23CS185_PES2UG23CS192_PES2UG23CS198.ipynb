# %%
#SRN:PES2UG23CS148 NAME:CHERUKURI VENKATA KARTIK
#Data cleaning
import pandas as pd
file_path = 'BankChurners.csv'

# Load the Titanic dataset
df = pd.read_csv(file_path)

# %%
df.describe(include="all")
# Out:
#            CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# count   1.012700e+04              10127  10127.000000  10127     10127.000000
# unique           NaN                  2           NaN      2              NaN
# top              NaN  Existing Customer           NaN      F              NaN
# freq             NaN               8500           NaN   5358              NaN
# mean    7.391776e+08                NaN     46.325960    NaN         2.346203
# std     3.690378e+07                NaN      8.016814    NaN         1.298908
# min     7.080821e+08                NaN     26.000000    NaN         0.000000
# 25%     7.130368e+08                NaN     41.000000    NaN         1.000000
# 50%     7.179264e+08                NaN     46.000000    NaN         2.000000
# 75%     7.731435e+08                NaN     52.000000    NaN         3.000000
# max     8.283431e+08                NaN     73.000000    NaN         5.000000
#
# ...

# %%
missing_counts = df.isnull().sum()
missing_rows = df.isnull().sum(axis=1)

# %%
empty_columns = missing_counts[missing_counts == len(df)].index
print("\nColumns that are completely empty:")
print(empty_columns)
# Out:
# Columns that are completely empty:
# Index(['Unnamed: 7'], dtype='object')

# %%
print("\nNumber of missing values per row:")
print(missing_rows.value_counts())
# Out:
# Number of missing values per row:
# 1    10127
# Name: count, dtype: int64

# %%
print("Missing values per column:")
print(missing_counts)
# Out:
# Missing values per column:
# CLIENTNUM                       0
# Attrition_Flag                  0
# Customer_Age                    0
# Gender                          0
# Dependent_count                 0
# Education_Level                 0
# Marital_Status                  0
# Unnamed: 7                  10127
# Card_Category                   0
# Months_on_book                  0
# Total_Relationship_Count        0
# Months_Inactive_12_mon          0
# Contacts_Count_12_mon           0
# Credit_Limit                    0
# Total_Revolving_Bal             0
# Avg_Open_To_Buy                 0
# Total_Amt_Chng_Q4_Q1            0
# Total_Trans_Amt                 0
# Total_Trans_Ct                  0
# Total_Ct_Chng_Q4_Q1             0
# Avg_Utilization_Ratio           0
# dtype: int64

# %%
df_cleaned = df.drop(columns=empty_columns)

# %%
print("\nColumns dropped due to being completely empty:")
print(empty_columns)
# Out:
# Columns dropped due to being completely empty:
# Index(['Unnamed: 7'], dtype='object')

# %%
print("\nDataFrame after dropping empty columns:")
df_cleaned.describe(include='all')
# Out:
# DataFrame after dropping empty columns:
#            CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# count   1.012700e+04              10127  10127.000000  10127     10127.000000
# unique           NaN                  2           NaN      2              NaN
# top              NaN  Existing Customer           NaN      F              NaN
# freq             NaN               8500           NaN   5358              NaN
# mean    7.391776e+08                NaN     46.325960    NaN         2.346203
# std     3.690378e+07                NaN      8.016814    NaN         1.298908
# min     7.080821e+08                NaN     26.000000    NaN         0.000000
# 25%     7.130368e+08                NaN     41.000000    NaN         1.000000
# 50%     7.179264e+08                NaN     46.000000    NaN         2.000000
# 75%     7.731435e+08                NaN     52.000000    NaN         3.000000
# ...

# %%
df_imputed = df_cleaned.copy()

# %%
for column in df_imputed.columns:
    if df_imputed[column].isnull().sum() > 0:
        if df_imputed[column].dtype == 'object':
            # Impute with mode for categorical columns
            mode_value = df_imputed[column].mode().iloc[0]
            df_imputed[column] = df_imputed[column].fillna(mode_value)
        else:
            # Impute with mean for numerical columns
            mean_value = df_imputed[column].mean()
            df_imputed[column] = df_imputed[column].fillna(mean_value)

# %%
print("\nDataFrame after imputing missing values:")
df_imputed.describe(include='all')
# Out:
# DataFrame after imputing missing values:
#            CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# count   1.012700e+04              10127  10127.000000  10127     10127.000000
# unique           NaN                  2           NaN      2              NaN
# top              NaN  Existing Customer           NaN      F              NaN
# freq             NaN               8500           NaN   5358              NaN
# mean    7.391776e+08                NaN     46.325960    NaN         2.346203
# std     3.690378e+07                NaN      8.016814    NaN         1.298908
# min     7.080821e+08                NaN     26.000000    NaN         0.000000
# 25%     7.130368e+08                NaN     41.000000    NaN         1.000000
# 50%     7.179264e+08                NaN     46.000000    NaN         2.000000
# 75%     7.731435e+08                NaN     52.000000    NaN         3.000000
# ...

# %%
print("\nDuplicate rows:")
df_imputed[df_imputed.duplicated(keep='first')]
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [CLIENTNUM, Attrition_Flag, Customer_Age, Gender, Dependent_count, Education_Level, Marital_Status, Card_Category, Months_on_book, Total_Relationship_Count, Months_Inactive_12_mon, Contacts_Count_12_mon, Credit_Limit, Total_Revolving_Bal, Avg_Open_To_Buy, Total_Amt_Chng_Q4_Q1, Total_Trans_Amt, Total_Trans_Ct, Total_Ct_Chng_Q4_Q1, Avg_Utilization_Ratio]
# Index: []

# %%
# Handle duplicates
df_final = df_imputed.drop_duplicates()

# %%
print("\nNumber of duplicate rows removed:")
print(len(df_imputed) - len(df_final))
# Out:
# Number of duplicate rows removed:
# 0

# %%
print("\nDataFrame after removing duplicates:")
df_final.describe(include='all')
# Out:
# DataFrame after removing duplicates:
#            CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# count   1.012700e+04              10127  10127.000000  10127     10127.000000
# unique           NaN                  2           NaN      2              NaN
# top              NaN  Existing Customer           NaN      F              NaN
# freq             NaN               8500           NaN   5358              NaN
# mean    7.391776e+08                NaN     46.325960    NaN         2.346203
# std     3.690378e+07                NaN      8.016814    NaN         1.298908
# min     7.080821e+08                NaN     26.000000    NaN         0.000000
# 25%     7.130368e+08                NaN     41.000000    NaN         1.000000
# 50%     7.179264e+08                NaN     46.000000    NaN         2.000000
# 75%     7.731435e+08                NaN     52.000000    NaN         3.000000
# ...

# %%
# Handle outliers

# Function to identify outliers in a column
def identify_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# %%
for column in df_final.select_dtypes(include=['float64', 'int64']).columns:
    outliers = identify_outliers(df_final, column)
    if not outliers.empty:
        print(f"\nPotential outliers in column '{column}':")
        print(outliers[[column]])
# Out:
# Potential outliers in column 'Customer_Age':
#      Customer_Age
# 251            73
# 254            70
#
# Potential outliers in column 'Months_on_book':
#        Months_on_book
# 11                 54
# 18                 56
# 27                 56
# 39                 56
# 52                 54
# ...               ...
# 10054              15
# 10062              17
# 10069              14
# 10107              54
# 10114              15
#
# [386 rows x 1 columns]
#
# Potential outliers in column 'Months_Inactive_12_mon':
#        Months_Inactive_12_mon
# 12                          6
# 29                          0
# 31                          5
# 108                         0
# 118                         6
# ...                       ...
# 9964                        5
# 10028                       5
# 10035                       6
# 10049                       5
# 10066                       6
#
# [331 rows x 1 columns]
#
# ...

# %%
# Remove outliers
df_no_outliers = df_final.copy()  # Work with DataFrame after removing duplicates

for column in df_no_outliers.select_dtypes(include=['float64', 'int64']).columns:
    Q1 = df_no_outliers[column].quantile(0.25)
    Q3 = df_no_outliers[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_no_outliers = df_no_outliers[(df_no_outliers[column] >= lower_bound) & (df_no_outliers[column] <= upper_bound)]

# %%
print("\nNumber of rows before and after outlier removal:")
print("Before:", len(df_final))
print("After:", len(df_no_outliers))
# Out:
# Number of rows before and after outlier removal:
# Before: 10127
# After: 6463

# %%
print("\nDataFrame after handling outliers:")
df_no_outliers.describe(include='all')
# Out:
# DataFrame after handling outliers:
#            CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# count   6.463000e+03               6463   6463.000000   6463      6463.000000
# unique           NaN                  2           NaN      2              NaN
# top              NaN  Existing Customer           NaN      F              NaN
# freq             NaN               5380           NaN   3988              NaN
# mean    7.384725e+08                NaN     46.384032    NaN         2.389138
# std     3.633481e+07                NaN      7.506139    NaN         1.272785
# min     7.080833e+08                NaN     26.000000    NaN         0.000000
# 25%     7.130244e+08                NaN     41.000000    NaN         1.000000
# 50%     7.178004e+08                NaN     46.000000    NaN         2.000000
# 75%     7.722979e+08                NaN     52.000000    NaN         3.000000
# max     8.283431e+08                NaN     68.000000    NaN         5.000000
# ...

# %%
df_no_outliers.head()
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10  708790833  Existing Customer            42      M                5
# 14  712396908  Existing Customer            57      F                2
# 19  709327383  Existing Customer            45      F                2
# 21  708508758  Attrited Customer            62      F                0
# 23  811604133  Existing Customer            47      F                4
#
#    Education_Level Marital_Status Card_Category  Months_on_book  \
# 10      Uneducated        Unknown          Blue              31
# 14        Graduate        Married          Blue              48
# 19        Graduate        Married          Blue              37
# 21        Graduate        Married          Blue              49
# 23         Unknown         Single          Blue              36
#
#     Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
#Q1 Divide the features in the BankChurners dataset into appropriate data types (ordinal, nominal, interval, or ratio) and provide justification for each classification choice.
#SRN:PES2UG23CS148 NAME:CHERUKURI VENKATA KARTIK
#Using Box plots and histograms the concepts of data visualisation was applied and the dataset was differentiated
ordinal_features = ['Dependent_count', 'Customer_Age']

# Create box plots for each ordinal feature
plt.figure(figsize=(12, len(ordinal_features) * 4)) # Adjust height based on number of features
for i in range(len(ordinal_features)):
    plt.subplot(len(ordinal_features), 1, i + 1) # Create subplots for each feature
    sns.boxplot(y=df_no_outliers[ordinal_features[i]])
    plt.title(f'Box Plot of {ordinal_features[i]} After Removing Outliers')
    plt.xlabel(ordinal_features[i])

plt.tight_layout() # Adjust layout to prevent overlap
plt.show()
nominal_features = ['Gender', 'Attrition_Flag', 'Card_Category', 'Marital_Status', 'Education_Level', 'Income_Category']

# Define ratio features
ratio_features = ['Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
                  'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
                  'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
                  'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']

# Set the style of seaborn
sns.set(style="whitegrid")

# Create histograms for each ratio feature
plt.figure(figsize=(15, 12))  # Adjust figure size as needed

for i, feature in enumerate(ratio_features, 1):
    plt.subplot(4, 3, i)  # Adjust the number of rows and columns based on the number of features
    sns.histplot(df[feature], bins=30, kde=True)  # KDE adds a kernel density estimate line
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
#Q2 Identify and describe potential data issues, inconsistencies, or anomalies within the dataset. Describe your approach to cleaning and preprocessing the data to ensure accuracy and readiness for analysis.
#SRN:PES2UG23CS148 NAME:CHERUKURI VENKATA KARTIK
#The above question is solved in the process of data cleaning done in the above part, columns where there were no values were dropped values were imputed and outliers were removed.

# %%
#Q3Provide a summary of each feature’s central tendency and dispersion. Describe the best measures of central tendency for each attribute, and calculate standard deviation and range for all numerical columns.
#Name:Gavini Prithvi Ananya SRN:PES2UG23CS148
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  6.463000e+03   6463.000000      6463.000000     6463.000000
# mean   7.384725e+08     46.384032         2.389138       35.951106
# std    3.633481e+07      7.506139         1.272785        7.036630
# min    7.080833e+08     26.000000         0.000000       18.000000
# 25%    7.130244e+08     41.000000         1.000000       32.000000
# 50%    7.178004e+08     46.000000         2.000000       36.000000
# 75%    7.722979e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     68.000000         5.000000       53.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count               6463.000000             6463.000000
# mean                   3.939192                2.274486
# std                    1.514048                0.863391
# min                    1.000000                1.000000
# 25%                    3.000000                2.000000
# ...

# %%
#Q4 Plot both histograms and box plots for 'Customer_Age' and 'Credit_Limit'.
#Name:Gavini Prithvi Ananya SRN:PES2UG23CS148
# i) Identify the type of distribution each variable appears to have.
# Hint: Scale the visualizations to clearly depict the data distribution.
# ii) Determine how many outliers exist for each variable.
# iii) Bonus: After identifying the distribution types, make adjustmentsimport numpy as np
#	Histogram: The code generates histograms for ratio features (e.g., Months_on_book, Total_Trans_Amt, Credit_Limit). Histograms are used to show the distribution of numerical data.
# Kernel Density Estimate (KDE): The kde=True argument adds a smooth curve to the histogram, providing a better understanding of the underlying distribution of the data.
# Customization: The bins=20 argument controls the number of bins in the histogram to better visualize the data distribution.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import probplot

df['Customer_Age'].hist(bins=20)
plt.title('Customer_Age')
plt.xlabel(column)
plt.ylabel('Count')
plt.show()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import probplot

df['Credit_Limit'].hist(bins=20)
plt.title('Credit_Limit')
plt.xlabel(column)
plt.ylabel('Count')
plt.show()
import matplotlib.pyplot as plt
import numpy as np

# Identify numeric columns
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

sns.boxplot(df_no_outliers['Credit_Limit'])
plt.show()
import matplotlib.pyplot as plt
import numpy as np

# Identify numeric columns
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

sns.boxplot(df_no_outliers['Customer_Age'])
plt.show()

# %%
#Q5	Describe the steps you would take to adjust for outliers. Display the modified data with new box plots and histograms.
#Name:Gavini Prithvi Ananya SRN:PES2UG23CS148
#Histograms: Visualizes the distribution of numerical data.
# Step 1: We import necessary libraries and create a sample DataFrame containing potential outlier values.
# Step 2: We identify outliers using the Z-score method. A z-score greater than a threshold (commonly set at 3) indicates an outlier.
# Step 3: We use the IQR method to calculate the first and third quartiles (Q1 and Q3) and define lower and upper bounds for identifying outliers.
# Step 4: We demonstrate how to remove outliers from the dataset based on the IQR method.
# Step 5: Instead of removing them, we cap the outlier values to the defined bounds.
# Step 6: Finally, we visualize the data before and after handling the outliers using box plots.
# import matplotlib.pyplot as plt

# Select only numeric columns
numeric_columns = df.select_dtypes(include=[np.number])

# Looping through each numeric column to display the value counts
for column in numeric_columns.columns:
    df[column].hist(bins=40)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
  #Box Plots: Shows the spread and potential outliers in data.
import matplotlib.pyplot as plt
import numpy as np

# Identify numeric columns
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Determine the number of numeric columns
num_columns = len(numeric_columns)

# Dynamically determine the number of rows and columns for the subplots
nrows = int(np.ceil(num_columns / 3))
ncols = min(3, num_columns)

# Generate box plots for all numeric columns
df[numeric_columns].plot(kind='box', subplots=True, layout=(nrows, ncols), figsize=(12, 8), sharex=False, sharey=False)

# Adjust layout for better visibility
plt.tight_layout()
plt.show()

# %%
# 6: (PES2UG23CS192)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import probplot

plt.figure(figsize=(8,6))
probplot(df_no_outliers['Credit_Limit'],dist="norm",plot=plt)
plt.title("Normal Prob Plot")
plt.ylabel("Hell")
plt.xlabel("Hello")
plt.show()

# %%
7.#Correlation Analysis:Calculate the correlation of 'Customer_Age' with other numeric variables and identify the variable most strongly correlated with 'Credit_Limit'.
#PES2UG23CS185 DRISHTI GOLCHHA
correlation = df_no_outliers['Customer_Age'].corr(df['Credit_Limit'])
print("Correlation between Customer_Age and Credit_Limit:", correlation)
if correlation > 0.5:
    print("Strong positive relationship")
elif correlation > 0:
    print("Weak positive relationship")
elif correlation < -0.5:
    print("Strong negative relationship")
elif correlation < 0:
    print("Weak negative relationship")
else:
    print("No relationship")
# Out:
# Correlation between Customer_Age and Credit_Limit: 0.001984440046011024
# Weak positive relationship

# %%
# 8: (PES2UG23CS192)

subset_columns=['Customer_Age','Credit_Limit','Attrition_Flag']
df_clean=df_no_outliers[subset_columns].dropna()

sns.pairplot(df_clean,hue='Attrition_Flag',palette='coolwarm')
plt.show()

# %%
# 9: (PES2UG23CS192)
import pandas as pd
from scipy.stats import mannwhitneyu

churned_customers = df_no_outliers[df_no_outliers['Attrition_Flag'] == 'Attrited Customer']['Credit_Limit']
existing_customers = df_no_outliers[df_no_outliers['Attrition_Flag'] == 'Existing Customer']['Credit_Limit']

stat, p_value = mannwhitneyu(churned_customers, existing_customers)

print(f'Mann-Whitney U Statistic: {stat}')
print(f'P-value: {p_value}')

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in median Credit Limit.")
else:
    print("Fail to reject the null hypothesis: No significant difference in median Credit Limit.")
# Out:
# Mann-Whitney U Statistic: 2637549.5
# P-value: 8.557729802941619e-07
# Reject the null hypothesis: There is a significant difference in median Credit Limit.

# %%
# 10: (PES2UG23CS192)
import pandas as pd
import numpy as np
from scipy.stats import norm

churned_customers = df_no_outliers[df_no_outliers['Attrition_Flag'] == 'Attrited Customer']['Credit_Limit']
existing_customers = df_no_outliers[df_no_outliers['Attrition_Flag'] == 'Existing Customer']['Credit_Limit']

def margin_of_error(df_no_outliers, confidence_level=0.95):
    n = len(df_no_outliers)
    if n < 2:
        return None

    Q1 = np.percentile(df_no_outliers, 25)
    Q3 = np.percentile(df_no_outliers, 75)
    IQR = Q3 - Q1

    se_median = IQR / np.sqrt(n)

    z_score = norm.ppf((1 + confidence_level) / 2)

    margin_of_error = z_score * se_median

    return margin_of_error
moe_churned = margin_of_error(churned_customers)
moe_existing = margin_of_error(existing_customers)
print(f'Margin of Error for Churned Customers: {moe_churned}')
print(f'Margin of Error for Existing Customers: {moe_existing}')
# Out:
# Margin of Error for Churned Customers: 267.8582546846096
# Margin of Error for Existing Customers: 123.05808839846934

# %%
#11.Linear Regression Analysis:Use 'Customer_Age' and 'Total_Trans_Amt' to build a linear regression model predicting 'Credit_Limit'

#PES2UG23CS185 DRISHTI GOLCHHA
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
print(df_no_outliers.head())
X = df_no_outliers[['Customer_Age', 'Total_Trans_Amt']]
y = df_no_outliers['Credit_Limit']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
predictions = model.predict(X)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(df_no_outliers['Customer_Age'], y, color='blue', label='Actual Credit Limit')
plt.scatter(df_no_outliers['Customer_Age'], predictions, color='red', label='Predicted Credit Limit', alpha=0.5)
plt.title('Customer Age vs Credit Limit')
plt.xlabel('Customer Age')
plt.ylabel('Credit Limit')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(df_no_outliers['Total_Trans_Amt'], y, color='blue', label='Actual Credit Limit')
plt.scatter(df_no_outliers['Total_Trans_Amt'], predictions, color='red', label='Predicted Credit Limit', alpha=0.5)
plt.title('Total Transaction Amount vs Credit Limit')
plt.xlabel('Total Transaction Amount')
plt.ylabel('Credit Limit')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10  708790833  Existing Customer            42      M                5
# 14  712396908  Existing Customer            57      F                2
# 19  709327383  Existing Customer            45      F                2
# 21  708508758  Attrited Customer            62      F                0
# 23  811604133  Existing Customer            47      F                4
#
#    Education_Level Marital_Status Card_Category  Months_on_book  \
# 10      Uneducated        Unknown          Blue              31
# 14        Graduate        Married          Blue              48
# 19        Graduate        Married          Blue              37
# 21        Graduate        Married          Blue              49
# 23         Unknown         Single          Blue              36
#
#     Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
#12.Feature Engineering:Given 'Customer_Age', 'Credit_Limit', and 'Total_Trans_Amt', propose two additional features that could improve the prediction of 'Credit_Limit'.
#PES2UG23CS185 DRISHTI GOLCHHA
import pandas as pd

print(df_no_outliers.head())

# Feature Engineering
# 1. Age-to-Credit Ratio
df_no_outliers['Age_to_Credit_Ratio'] = df_no_outliers['Customer_Age'] / df_no_outliers['Credit_Limit']

# 2. Transaction Amount per Age
df_no_outliers['Trans_Amt_per_Age'] = df_no_outliers['Total_Trans_Amt'] / df_no_outliers['Customer_Age']

print(df_no_outliers[['Customer_Age', 'Credit_Limit', 'Total_Trans_Amt', 'Age_to_Credit_Ratio', 'Trans_Amt_per_Age']].head())

df_no_outliers.to_csv('bankChurned_with_features.csv', index=False)
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10  708790833  Existing Customer            42      M                5
# 14  712396908  Existing Customer            57      F                2
# 19  709327383  Existing Customer            45      F                2
# 21  708508758  Attrited Customer            62      F                0
# 23  811604133  Existing Customer            47      F                4
#
#    Education_Level Marital_Status Card_Category  Months_on_book  \
# 10      Uneducated        Unknown          Blue              31
# 14        Graduate        Married          Blue              48
# 19        Graduate        Married          Blue              37
# 21        Graduate        Married          Blue              49
# 23         Unknown         Single          Blue              36
#
#     Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...
